# %%
import openslide 
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
he_slide = openslide.open_slide("/home/heckerm/data/CK/R5328_21_HE.mrxs")
ck_slide = openslide.open_slide("/home/heckerm/data/CK/R5328_21_CK.mrxs")

# %%
image_he = he_slide.get_thumbnail((1024, 1024))
image_he
# Out:
# <PIL.Image.Image image mode=RGB size=423x1024>

# %%
image_ck = ck_slide.get_thumbnail((1024,1024))
image_ck
# Out:
# <PIL.Image.Image image mode=RGB size=423x1024>

# %%
pred_slide = openslide.open_slide("slide_R5328_21_fm.tif")
image_pred = pred_slide.get_thumbnail((1024,1024))
image_pred
# Out:
# <PIL.Image.Image image mode=RGB size=423x1024>

# %%
pred_slide.read_region((28850, 59500), level=1, size=(512,512))
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512>

# %%
he_slide.read_region((28850, 59500), level=1, size=(512,512))
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512>
